# %% [markdown]
# <a href="https://colab.research.google.com/github/CyberDude0/ML/blob/dataproc/imagee1(comp_vision).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
#checking version
print(cv2.__version_)

# %%
#images reading
img=cv2.imread('BFCA3782.JPG',1)
img1=cv2.imread('BFCA3782.JPG',2)
img2=cv2.imread('BFCA3782.JPG',-1)

# %%
print(img)
# Out:
# [[[199 190 181]
#   [199 190 181]
#   [199 190 181]
#   ...
#   [184 170 164]
#   [184 170 164]
#   [186 170 164]]
#
#  [[199 190 181]
#   [199 190 181]
#   [199 190 181]
#   ...
#   [185 171 165]
#   [184 170 164]
#   [186 170 164]]
#
#  [[199 189 182]
#   [199 189 182]
#   [200 189 181]
#   ...
#   [185 171 165]
#   [185 171 165]
#   [184 170 164]]
#
#  ...
#
#  [[180 190 207]
#   [182 192 209]
#   [185 194 208]
#   ...
#   [174 180 187]
#   [174 180 187]
#   [176 182 189]]
#
#  [[169 176 196]
#   [170 177 197]
#   [173 178 199]
#   ...
#   [174 180 187]
#   [174 180 187]
#   [176 182 189]]
#
#  [[152 158 181]
#   [153 159 182]
#   [154 158 182]
#   ...
#   [174 180 187]
#   [174 180 187]
#   [175 181 188]]]

# %%
#print shape
print(img.shape)
# Out:
# (6000, 4000, 3)

# %%
#type
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
# to display image
plt.imshow(img)
plt.imshow(img1)
plt.imshow(img2)

# %%
#wait for window to close
#plt.waitkey(0)    #mili /micro seconds
